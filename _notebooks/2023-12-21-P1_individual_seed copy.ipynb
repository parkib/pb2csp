# %% [markdown]
# ---
# comments: true
# layout: notebook
# title: Individual Seed
# description: Team teach on safe computing
# type: collab
# author: Prakruti
# toc: true
# courses: { csp: {week: 16} }
# ---

# %% [markdown]
# ## Individual
#
# I've made significant progress in the class, expanding my coding skills and gaining a deep understanding of various coding terms. Through consistent efforts and numerous commits, I've dedicated myself to enhancing my blog, showcasing continuous improvement in my coding journey.
#
# ![image.png](attachment:image.png)
#
# ## Commits
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## GitHub Pages and AP Work
#
# https://parkib.github.io/pb2csp/ my blog page!! check it out.
#
# CPT Trimester 2 Review: https://github.com/parkib/pb2csp/issues/2

# %% [markdown]
# ## COLLEGE BOARD MCQ
#
# College Board MCQ corrections: https://parkib.github.io/pb2csp//2023/12/21/CB-MCQ_IPYNB_2_.html

# %% [markdown]
# ## WHAT IM DOING RIGHT NOw!!
#
# debugging
#
# https://github.com/parkib/pb2csp/issues/3
